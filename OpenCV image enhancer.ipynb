# %% [markdown]
# ## OpenCV on dark skinned people

# %%
import sys
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
from PIL import ImageEnhance

# %% [markdown]
# ### Image enhancement using PIL library

# %%
image = Image.open('Dataset/3.jpg')
#stored my photos in Dataset folder

# image.show()
plt.imshow(image)

# %%
#PIL library can enhance photos in 4 aspects: Brightness, Contrast, Color, Sharpness
image1 = ImageEnhance.Brightness(image1).enhance(1.2)
image1 = ImageEnhance.Contrast(image).enhance(1)
image1 = ImageEnhance.Color(image1).enhance(1)
image1 = ImageEnhance.Sharpness(image1).enhance(1.4)
plt.imshow(image1)

# %% [markdown]
# #### Convert PIL image into cv2

# %%
pil_image = image1.convert('RGB') 
open_cv_image = np.array(pil_image) 
# Convert RGB to BGR 
open_cv_image = open_cv_image[:, :, ::-1].copy()

# %% [markdown]
# ### OpenCV Facial Detection

# %% [markdown]
# #### Running the model

# %%
#     img = cv2.resize(img, (0,0), fx =0.5, fy=0.5)

#     if colour_code == 1:
#         colourised_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     elif colour_code == 2:
#         colourised_image = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
#     elif colour_code == 3:
#         colourised_image = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
#     elif colour_code == 4:
#         colourised_image = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

def face_detector(image_var):
    gray = cv2.cvtColor(open_cv_image, cv2.COLOR_BGR2GRAY)

    face_cascade = cv2.CascadeClassifier('C:/Users/rrmsf/Desktop/OpenCV/haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.1, 6, minSize=(30, 30))


    # Draw rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 255), 1)


    # Display the output
    cv2.imshow('Image', image_var)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
face_detector(open_cv_image)
